# %% [markdown]
# # 【课程 6】预训练模型与微调（SOTA 方案）
#
# **核心内容**：
# ① 预训练模型选型：Wav2Vec2/HuBERT（SER 场景适配原则）；
# ② 微调全流程：数据适配、冻结策略、学习率调度、梯度累积；
# ③ 微调优化：小样本适配、跨数据集迁移、模型轻量化；
# ④ 效果验证：预训练模型 vs 混合模型 vs 单一模型；
#
# **工具输出**：预训练模型微调一键脚本（支持自定义数据集 / 模型）；
#
# **定位**：掌握工业级 SER 的 SOTA 解法，理解「预训练 + 微调」的核心逻辑
